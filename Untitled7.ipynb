# %%
# !pip install pandas

# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20230311ubuntu0.22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.15).
# gnupg is already the newest version (2.2.27-3ubuntu2.1).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
# gpg: cannot open '/dev/tty': No such device or address
# curl: (23) Failed writing body
# deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_20.x nodistro main
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# nodejs is already the newest version (20.10.0-1nodesource1).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
# v20.10.0

# %%
filename = 'Produk_layanan.csv'
search_keyword = 'alfamart layanan'
limit = 500

# !npx --yes tweet-harvest@latest -o "{filename}" -s "{search_keyword}" -1 {limit} --token ""
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
# ? What's your Twitter auth token? › 78? What's your Twitter auth token? › *78? What's your Twitter auth token? › **78? What's your Twitter auth token? › ***78? What's your Twitter auth token? › ****78? What's your Twitter auth token? › *****78? What's your Twitter auth token? › ******78? What's your Twitter auth token? › *******78? What's your Twitter auth token? › ********78? What's your Twitter auth token? › *********78? What's your Twitter auth token? › **********78? What's your Twitter auth token? › ***********78? What's your Twitter auth token? › ************78? What's your Twitter auth token? › *************78? What's your Twitter auth token? › **************78? What's your Twitter auth token? › ***************78? What's your Twitter auth token? › ****************78? What's your Twitter auth token? › *****************78? What's your Twitter auth token? › ******************78? What's your Twitter auth token? › *******************78? What's your Twitter auth token? › ********************78? What's your Twitter auth token? › *********************78? What's your Twitter auth token? › **********************78? What's your Twitter auth token? › ***********************78? What's your Twitter auth token? › ************************78? What's your Twitter auth token? › *************************78? What's your Twitter auth token? › **************************78? What's your Twitter auth token? › ***************************78? What's your Twitter auth token? › ****************************78? What's your Twitter auth token? › *****************************78? What's your Twitter auth token? › ******************************78? What's your Twitter auth token? › *******************************78? What's your Twitter auth token? › ********************************78? What's your Twitter auth token? › *********************************78? What's your Twitter auth token? › **********************************78? What's your Twitter auth token? › ***********************************78? What's your Twitter auth token? › ************************************78? What's your Twitter auth token? › *************************************78? What's your Twitter auth token? › **************************************78? What's your Twitter auth token? › ***************************************78? What's your Twitter auth token? › ****************************************78✔ What's your Twitter auth token? … ****************************************78
# ? How many tweets do you want to crawl? › 78? How many tweets do you want to crawl? › 478? How many tweets do you want to crawl? › 4378? How many tweets do you want to crawl? › 43878? How many tweets do you want to crawl? › 438978? How many tweets do you want to crawl? › 4389878? How many tweets do you want to crawl? › 43898078? How many tweets do you want to crawl? › 438980278? How many tweets do you want to crawl? › 4389802178? How many tweets do you want to crawl? › 43898021178? How many tweets do you want to crawl? › 438980211078? How many tweets do you want to crawl? › 4389802110178? How many tweets do you want to crawl? › 43898021101278? How many tweets do you want to crawl? › 438980211012278? How many tweets do you want to crawl? › 4389802110122778? How many tweets do you want to crawl? › 43898021101227678? How many tweets do you want to crawl? › 438980211012276378? How many tweets do you want to crawl? › 4389802110122763078? How many tweets do you want to crawl? › 43898021101227630078? How many tweets do you want to crawl? › 438980211012276330078? How many tweets do you want to crawl? › 4389802110122763000078? How many tweets do you want to crawl? › 43898021101227630000078? How many tweets do you want to crawl? › 4.389802110122764e+2178? How many tweets do you want to crawl? › 4.389802110122763e+2278? How many tweets do you want to crawl? › 4.389802110122763e+2378? How many tweets do you want to crawl? › 4.3898021101227636e+2478✔ How many tweets do you want to crawl? … 4.3898021101227636e+2478
#
# up to date, audited 4 packages in 959ms
#
# found 0 vulnerabilities
# Installing dependencies...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-freefont-ttf is already the newest version (20120503-10build1).
# fonts-liberation is already the newest version (1:1.07.4-11).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libatspi2.0-0 is already the newest version (2.44.0-3).
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libnspr4 is already the newest version (2:4.32-3build1).
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# xfonts-scalable is already the newest version (1:1.0.3-1.2ubuntu1).
# fonts-ipafont-gothic is already the newest version (00303-21ubuntu1).
# fonts-tlwg-loma-otf is already the newest version (1:0.7.3-1).
# fonts-unifont is already the newest version (1:14.0.01-1).
# fonts-wqy-zenhei is already the newest version (0.9.45-8).
# xfonts-cyrillic is already the newest version (1:1.0.5).
# fonts-noto-color-emoji is already the newest version (2.042-0ubuntu0.22.04.1).
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.7).
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.2).
# libgbm1 is already the newest version (23.0.4-0ubuntu1~22.04.1).
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.2).
# libnss3 is already the newest version (2:3.68.2-0ubuntu1.2).
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.5).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
#
# Opening twitter search page...
#
#
# Filling in keywords: alfamart layanan
#
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Produk_layanan.csv
# Total tweets saved: 20
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Produk_layanan.csv
# Total tweets saved: 40
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Produk_layanan.csv
# Total tweets saved: 60
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Produk_layanan.csv
# Total tweets saved: 80
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/Produk_layanan.csv
# Total tweets saved: 93
#
# Got some tweets, saving to file...
# No more tweets found, please check your search criteria and csv file result
# Scrolling more...
# Scrolling more...
# Scrolling more...
# Scrolling more...
# Already got 93 tweets, done scrolling...

# %%
import pandas as pd

file_path = f"tweets-data/{filename}"

# %%
data = pd.read_csv(file_path, delimiter=",")

display(data)
# Out:
#                         created_at               id_str  \
# 0   Sun Apr 09 13:04:08 +0000 2023  1645049960776466432
# 1   Fri Apr 07 00:30:47 +0000 2023  1644135598758989825
# 2   Sun Sep 10 14:49:21 +0000 2023  1700884169071722636
# 3   Mon Jan 16 08:04:31 +0000 2023  1614896364747657217
# 4   Tue Aug 01 09:21:45 +0000 2023  1686306213238071298
# ..                             ...                  ...
# 88  Wed Jan 03 01:25:14 +0000 2024  1742356413245165573
# 89  Fri Dec 29 14:44:35 +0000 2023  1740745634968486386
# 90  Thu Dec 28 03:08:42 +0000 2023  1740208124144062734
# 91  Wed Dec 27 04:09:59 +0000 2023  1739861157127839886
# 92  Fri Dec 29 16:01:44 +0000 2023  1740765050846196125
#
#                                             full_text  quote_count  \
# 0   INFO LAYANAN MASYARAKAT PERSKINCAREAN DI ALFAM...            1
# 1   Massive shout out to my ex karena dulu pernah ...            0
# 2   Alfamart Berikan Layanan Kesehatan Gratis kepa...            0
# 3   Alhamdulillah Skrg @ShopeeID mengenakan Biaya ...            0
# 4   TIPE TOKO CONVENIENCE ALFAMART ADALAH | KONSEP...            0
# ..                                                ...          ...
# 88  #INFOTRANSJAKARTA | Layanan Mikrotrans JAK 80:...            0
# 89  @txtfromkeuangan Tambah min alfamart itu layan...            0
# 90  @alfamart Perbaikin layanan cs! Minta di dm ma...            0
# 91  @alfamart Min  tolong sampaikan ke divisi CS  ...            0
# 92  @txtfromkeuangan aku termasuk yg terbantu bgt ...            0
#
#     reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0             9              0              10   in  1019912145666945024
# 1             3              0               0   in  1397278044771938304
# 2             0              0               0   in  1140052359399129088
# 3             2              0               2   in   950642473881120770
# 4             0              0               0   in           1156583228
# ..          ...            ...             ...  ...                  ...
# 88            2              0               5   in            104556071
# 89            0              0               0   in   788400966030675969
# 90            0              0               0   in            191347030
# 91            1              0               0   in            191347030
# 92            0              1               0   in            394516140
#
#     conversation_id_str         username  \
# 0   1645049960776466432         mdlwlrma
# 1   1644135598758989825      kingslayeur
# 2   1700884169071722636      BacamalangC
# 3   1614896364747657217  yosefabdullah17
# 4   1686306213238071298      rajarakindo
# ..                  ...              ...
# 88  1742356413245165573  PT_Transjakarta
# 89  1740712242633662836  iskandar_shodik
# 90  1740203102257721435    eristasiregar
# 91  1739849310601420809    eristasiregar
# 92  1740712242633662836     margarinbeku
#
#                                             tweet_url  \
# 0   https://twitter.com/mdlwlrma/status/1645049960...
# 1   https://twitter.com/kingslayeur/status/1644135...
# 2   https://twitter.com/BacamalangC/status/1700884...
# 3   https://twitter.com/yosefabdullah17/status/161...
# 4   https://twitter.com/rajarakindo/status/1686306...
# ..                                                ...
# 88  https://twitter.com/PT_Transjakarta/status/174...
# 89  https://twitter.com/iskandar_shodik/status/174...
# 90  https://twitter.com/eristasiregar/status/17402...
# 91  https://twitter.com/eristasiregar/status/17398...
# 92  https://twitter.com/margarinbeku/status/174076...
#
#                                           image_url  \
# 0   https://pbs.twimg.com/media/FtRkNzsaAAAJEzd.jpg
# 1   https://pbs.twimg.com/media/FtEkm8caMAAt96D.jpg
# 2                                               NaN
# 3   https://pbs.twimg.com/media/FmlDrmxaAAMIG-A.jpg
# 4                                               NaN
# ..                                              ...
# 88                                              NaN
# 89                                              NaN
# 90                                              NaN
# 91                                              NaN
# 92                                              NaN
#
#                       location
# 0                          NaN
# 1                        Naya.
# 2                          NaN
# 3                          NaN
# 4     Kp.Rambutan, DKI Jakarta
# ..                         ...
# 88                     Jakarta
# 89                         NaN
# 90                         +62
# 91                         +62
# 92  Kota Semarang, Jawa Tengah
#
# [93 rows x 14 columns]

# %%
df = data.drop(columns=['created_at', 'id_str', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'lang', 'conversation_id_str', 'username', 'tweet_url'])
df
# Out:
#                                             full_text          user_id_str  \
# 0   INFO LAYANAN MASYARAKAT PERSKINCAREAN DI ALFAM...  1019912145666945024
# 1   Massive shout out to my ex karena dulu pernah ...  1397278044771938304
# 2   Alfamart Berikan Layanan Kesehatan Gratis kepa...  1140052359399129088
# 3   Alhamdulillah Skrg @ShopeeID mengenakan Biaya ...   950642473881120770
# 4   TIPE TOKO CONVENIENCE ALFAMART ADALAH | KONSEP...           1156583228
# ..                                                ...                  ...
# 88  #INFOTRANSJAKARTA | Layanan Mikrotrans JAK 80:...            104556071
# 89  @txtfromkeuangan Tambah min alfamart itu layan...   788400966030675969
# 90  @alfamart Perbaikin layanan cs! Minta di dm ma...            191347030
# 91  @alfamart Min  tolong sampaikan ke divisi CS  ...            191347030
# 92  @txtfromkeuangan aku termasuk yg terbantu bgt ...            394516140
#
#                                           image_url  \
# 0   https://pbs.twimg.com/media/FtRkNzsaAAAJEzd.jpg
# 1   https://pbs.twimg.com/media/FtEkm8caMAAt96D.jpg
# 2                                               NaN
# 3   https://pbs.twimg.com/media/FmlDrmxaAAMIG-A.jpg
# 4                                               NaN
# ..                                              ...
# 88                                              NaN
# 89                                              NaN
# 90                                              NaN
# 91                                              NaN
# 92                                              NaN
#
#                       location
# 0                          NaN
# 1                        Naya.
# 2                          NaN
# 3                          NaN
# 4     Kp.Rambutan, DKI Jakarta
# ..                         ...
# 88                     Jakarta
# 89                         NaN
# 90                         +62
# 91                         +62
# 92  Kota Semarang, Jawa Tengah
#
# [93 rows x 4 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.to_csv('/content/drive/My Drive/Crawling_Data/Produk_layanan.csv')

# %%
df1 = pd.read_csv('/content/drive/My Drive/Crawling_Data/Produk_layanan.csv')
df1
# Out:
#     Unnamed: 0                                          full_text  \
# 0            0  INFO LAYANAN MASYARAKAT PERSKINCAREAN DI ALFAM...
# 1            1  Massive shout out to my ex karena dulu pernah ...
# 2            2  Alfamart Berikan Layanan Kesehatan Gratis kepa...
# 3            3  Alhamdulillah Skrg @ShopeeID mengenakan Biaya ...
# 4            4  TIPE TOKO CONVENIENCE ALFAMART ADALAH | KONSEP...
# ..         ...                                                ...
# 88          88  #INFOTRANSJAKARTA | Layanan Mikrotrans JAK 80:...
# 89          89  @txtfromkeuangan Tambah min alfamart itu layan...
# 90          90  @alfamart Perbaikin layanan cs! Minta di dm ma...
# 91          91  @alfamart Min  tolong sampaikan ke divisi CS  ...
# 92          92  @txtfromkeuangan aku termasuk yg terbantu bgt ...
#
#             user_id_str                                        image_url  \
# 0   1019912145666945024  https://pbs.twimg.com/media/FtRkNzsaAAAJEzd.jpg
# 1   1397278044771938304  https://pbs.twimg.com/media/FtEkm8caMAAt96D.jpg
# 2   1140052359399129088                                              NaN
# 3    950642473881120770  https://pbs.twimg.com/media/FmlDrmxaAAMIG-A.jpg
# 4            1156583228                                              NaN
# ..                  ...                                              ...
# 88            104556071                                              NaN
# 89   788400966030675969                                              NaN
# 90            191347030                                              NaN
# 91            191347030                                              NaN
# 92            394516140                                              NaN
#
#                       location
# 0                          NaN
# 1                        Naya.
# 2                          NaN
# 3                          NaN
# 4     Kp.Rambutan, DKI Jakarta
# ..                         ...
# 88                     Jakarta
# 89                         NaN
# 90                         +62
# 91                         +62
# 92  Kota Semarang, Jawa Tengah
#
# [93 rows x 5 columns]

# %%
# !pip install contractions
# !pip install emoji
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 2.4 MB/s eta 0:00:00
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.0.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 12.6 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.0.0 textsearch-0.0.24
# Collecting emoji
#   Downloading emoji-2.9.0-py2.py3-none-any.whl (397 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.5/397.5 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.9.0

# %%
import emoji
import contractions
import re

# %%
# Nama
# NIM
# 19/10/2023

# Ketik Manual dari picture yang di share

# membersihkan teks dalam tweet.
def cleansing(tweet):
  # mengganti semua kemunculan string 'RT ' dengan string kosong ('') dalam teks tweet.
  t1 = re.sub('RT\s','',tweet)

  # mengganti semua kemunculan username Twitter dalam teks t1 dengan string kosong ('').
  # '\B' digunakan untuk mencocokkan tepi kata
  t2 = re.sub('\B@\w+','',t1)

  # menggantikan semua emoji dalam teks t2 dengan teks yang sesuai.
  t3 = emoji.demojize(t2)

  # mengganti semua URL yang dimulai dengan 'http' atau 'https' dalam teks t3 dengan string kosong ('').
  t4 = re.sub('(http|https):\/\/\S+','',t3)

  # menghilangkan satu atau lebih tanda pagar '#' dalam teks t4.
  t5 = re.sub('#+','',t4)

  # menyimpan teks t5 dalam huruf kecil (lowercase).
  t6= t5.lower()

  # mengganti semua pengulangan karakter yang terdiri dari dua atau lebih karakter dengan hanya dua karakter yang sama.
  t7 = re.sub(r'(.)\1+',r'\1\1', t6)

  # menghilangkan pengulangan tanda tanya, titik, atau tanda seru yang muncul berurutan dalam teks t7.
  t8 = re.sub(r'[\?\.\!]+(?=[\?.\!])','',t7)

  # digunakan untuk mengganti semua karakter yang bukan huruf alfabet (a-z dan A-Z) dengan spasi. Hasilnya akan disimpan di t9.
  t9 = re.sub(r'[^a-zA-Z]', ' ', t8)

  t10 = contractions.fix(t9)

  return t10

# %%
for i, r in df.iterrows():
  y = cleansing(r['full_text'])
  df1.loc[i, 'full_text'] = y

# %%
df1
# Out:
#     Unnamed: 0                                          full_text  \
# 0            0  info layanan masyarakat perskincarean di alfam...
# 1            1  massive shout out to my ex karena dulu pernah ...
# 2            2  alfamart berikan layanan kesehatan gratis kepa...
# 3            3  alhamdulillah skrg  mengenakan biaya topup sal...
# 4            4  tipe toko convenience alfamaadalah   konsep  p...
# ..         ...                                                ...
# 88          88  infotransjakarta   layanan mikrotrans jak     ...
# 89          89   tambah min alfamart itu layanan pesan antarny...
# 90          90   perbaikin layanan cs  minta di dm malah respo...
# 91          91   min  tolong sampaikan ke divisi cs  perbaikin...
# 92          92   aku termasuk yg terbantu bgt sama layanan alf...
#
#             user_id_str                                        image_url  \
# 0   1019912145666945024  https://pbs.twimg.com/media/FtRkNzsaAAAJEzd.jpg
# 1   1397278044771938304  https://pbs.twimg.com/media/FtEkm8caMAAt96D.jpg
# 2   1140052359399129088                                              NaN
# 3    950642473881120770  https://pbs.twimg.com/media/FmlDrmxaAAMIG-A.jpg
# 4            1156583228                                              NaN
# ..                  ...                                              ...
# 88            104556071                                              NaN
# 89   788400966030675969                                              NaN
# 90            191347030                                              NaN
# 91            191347030                                              NaN
# 92            394516140                                              NaN
#
#                       location
# 0                          NaN
# 1                        Naya.
# 2                          NaN
# 3                          NaN
# 4     Kp.Rambutan, DKI Jakarta
# ..                         ...
# 88                     Jakarta
# 89                         NaN
# 90                         +62
# 91                         +62
# 92  Kota Semarang, Jawa Tengah
#
# [93 rows x 5 columns]

# %%
df1.to_csv('/content/drive/My Drive/Crawling_Data/Produk_layanan2.csv')

# %%
# !pip install nltk

import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
from nltk.corpus import stopwords

nltk.download('wordnet')
from nltk import pos_tag
from nltk.corpus import wordnet

nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
pos_dict = {'J':wordnet.ADJ, 'v':wordnet.VERB, 'N':wordnet.NOUN, 'R':wordnet.ADV}

# %%
# Nama
# NIM
# 19/10/2023

def token_stop_pos(text):
  tags = pos_tag(word_tokenize(text))
  newlist = []
  for word, tag in tags:
    if word.lower() not in set(stopwords.words('english')):
      newlist.append(tuple([word, pos_dict.get(tag[0])]))
  return newlist

# %%
df1['POS tagged'] = df1['full_text'].apply(token_stop_pos)

# %%
df1
# Out:
#     Unnamed: 0                                          full_text  \
# 0            0  info layanan masyarakat perskincarean di alfam...
# 1            1  massive shout out to my ex karena dulu pernah ...
# 2            2  alfamart berikan layanan kesehatan gratis kepa...
# 3            3  alhamdulillah skrg  mengenakan biaya topup sal...
# 4            4  tipe toko convenience alfamaadalah   konsep  p...
# ..         ...                                                ...
# 88          88  infotransjakarta   layanan mikrotrans jak     ...
# 89          89   tambah min alfamart itu layanan pesan antarny...
# 90          90   perbaikin layanan cs  minta di dm malah respo...
# 91          91   min  tolong sampaikan ke divisi cs  perbaikin...
# 92          92   aku termasuk yg terbantu bgt sama layanan alf...
#
#             user_id_str                                        image_url  \
# 0   1019912145666945024  https://pbs.twimg.com/media/FtRkNzsaAAAJEzd.jpg
# 1   1397278044771938304  https://pbs.twimg.com/media/FtEkm8caMAAt96D.jpg
# 2   1140052359399129088                                              NaN
# 3    950642473881120770  https://pbs.twimg.com/media/FmlDrmxaAAMIG-A.jpg
# 4            1156583228                                              NaN
# ..                  ...                                              ...
# 88            104556071                                              NaN
# 89   788400966030675969                                              NaN
# 90            191347030                                              NaN
# 91            191347030                                              NaN
# 92            394516140                                              NaN
#
#                       location  \
# 0                          NaN
# 1                        Naya.
# 2                          NaN
# 3                          NaN
# 4     Kp.Rambutan, DKI Jakarta
# ..                         ...
# 88                     Jakarta
# 89                         NaN
# 90                         +62
# 91                         +62
# 92  Kota Semarang, Jawa Tengah
#
#                                            POS tagged
# 0   [(info, n), (layanan, n), (masyarakat, n), (pe...
# 1   [(massive, a), (shout, n), (ex, a), (karena, N...
# 2   [(alfamart, r), (berikan, a), (layanan, n), (k...
# 3   [(alhamdulillah, n), (skrg, n), (mengenakan, n...
# 4   [(tipe, a), (toko, n), (convenience, n), (alfa...
# ..                                                ...
# 88  [(infotransjakarta, n), (layanan, n), (mikrotr...
# 89  [(tambah, n), (min, n), (alfamart, None), (itu...
# 90  [(perbaikin, n), (layanan, n), (cs, n), (minta...
# 91  [(min, n), (tolong, a), (sampaikan, a), (ke, n...
# 92  [(aku, n), (termasuk, n), (yg, n), (terbantu, ...
#
# [93 rows x 6 columns]

# %%
# Nama
# NIM
# 19/10/2023

from textblob import TextBlob

def getSubjectivity(tagged_words):
  text = ' '.join([word for word, pos_tag in tagged_words])
  return TextBlob(text).sentiment.subjectivity

def getPolarity(tagged_words):
  text = ' '.join([word for word, pos_tag in tagged_words])
  return TextBlob(text).sentiment.polarity

def analyze(score):
  if score<0:
    return 'Negative'
  elif score==0:
    return 'Neutral'
  else:
    return 'Positive'

# %%
# Nama
# NIM
# 19/10/2023

final_data = pd.DataFrame(df1[['user_id_str','POS tagged']])
final_data
# Out:
#             user_id_str                                         POS tagged
# 0   1019912145666945024  [(info, n), (layanan, n), (masyarakat, n), (pe...
# 1   1397278044771938304  [(massive, a), (shout, n), (ex, a), (karena, N...
# 2   1140052359399129088  [(alfamart, r), (berikan, a), (layanan, n), (k...
# 3    950642473881120770  [(alhamdulillah, n), (skrg, n), (mengenakan, n...
# 4            1156583228  [(tipe, a), (toko, n), (convenience, n), (alfa...
# ..                  ...                                                ...
# 88            104556071  [(infotransjakarta, n), (layanan, n), (mikrotr...
# 89   788400966030675969  [(tambah, n), (min, n), (alfamart, None), (itu...
# 90            191347030  [(perbaikin, n), (layanan, n), (cs, n), (minta...
# 91            191347030  [(min, n), (tolong, a), (sampaikan, a), (ke, n...
# 92            394516140  [(aku, n), (termasuk, n), (yg, n), (terbantu, ...
#
# [93 rows x 2 columns]

# %%
# Nama
# NIM
# 19/10/2023

final_data['Subjectivity'] = final_data['POS tagged'].apply(getSubjectivity)
final_data['Polarity'] = final_data['POS tagged'].apply(getPolarity)
final_data['TextBlob'] = final_data['Polarity'].apply(analyze)

# %%
final_data
# Out:
#             user_id_str                                         POS tagged  \
# 0   1019912145666945024  [(info, n), (layanan, n), (masyarakat, n), (pe...
# 1   1397278044771938304  [(massive, a), (shout, n), (ex, a), (karena, N...
# 2   1140052359399129088  [(alfamart, r), (berikan, a), (layanan, n), (k...
# 3    950642473881120770  [(alhamdulillah, n), (skrg, n), (mengenakan, n...
# 4            1156583228  [(tipe, a), (toko, n), (convenience, n), (alfa...
# ..                  ...                                                ...
# 88            104556071  [(infotransjakarta, n), (layanan, n), (mikrotr...
# 89   788400966030675969  [(tambah, n), (min, n), (alfamart, None), (itu...
# 90            191347030  [(perbaikin, n), (layanan, n), (cs, n), (minta...
# 91            191347030  [(min, n), (tolong, a), (sampaikan, a), (ke, n...
# 92            394516140  [(aku, n), (termasuk, n), (yg, n), (terbantu, ...
#
#     Subjectivity  Polarity  TextBlob
# 0            0.0       0.0   Neutral
# 1            1.0       0.0   Neutral
# 2            0.0       0.0   Neutral
# 3            0.7       0.4  Positive
# 4            0.0       0.0   Neutral
# ..           ...       ...       ...
# 88           0.0       0.0   Neutral
# 89           0.0       0.0   Neutral
# 90           0.0       0.0   Neutral
# 91           0.0       0.0   Neutral
# 92           0.8       0.4  Positive
#
# [93 rows x 5 columns]

# %%
final_data.to_csv('/content/drive/My Drive/Crawling_Data/Produk_layanan3.csv')

# %%
df1 = pd.read_csv('/content/drive/My Drive/Crawling_Data/Produk_layanan3.csv')
df1
# Out:
#     Unnamed: 0          user_id_str  \
# 0            0  1019912145666945024
# 1            1  1397278044771938304
# 2            2  1140052359399129088
# 3            3   950642473881120770
# 4            4           1156583228
# ..         ...                  ...
# 88          88            104556071
# 89          89   788400966030675969
# 90          90            191347030
# 91          91            191347030
# 92          92            394516140
#
#                                            POS tagged  Subjectivity  Polarity  \
# 0   [('info', 'n'), ('layanan', 'n'), ('masyarakat...           0.0       0.0
# 1   [('massive', 'a'), ('shout', 'n'), ('ex', 'a')...           1.0       0.0
# 2   [('alfamart', 'r'), ('berikan', 'a'), ('layana...           0.0       0.0
# 3   [('alhamdulillah', 'n'), ('skrg', 'n'), ('meng...           0.7       0.4
# 4   [('tipe', 'a'), ('toko', 'n'), ('convenience',...           0.0       0.0
# ..                                                ...           ...       ...
# 88  [('infotransjakarta', 'n'), ('layanan', 'n'), ...           0.0       0.0
# 89  [('tambah', 'n'), ('min', 'n'), ('alfamart', N...           0.0       0.0
# 90  [('perbaikin', 'n'), ('layanan', 'n'), ('cs', ...           0.0       0.0
# 91  [('min', 'n'), ('tolong', 'a'), ('sampaikan', ...           0.0       0.0
# 92  [('aku', 'n'), ('termasuk', 'n'), ('yg', 'n'),...           0.8       0.4
#
#     TextBlob
# 0    Neutral
# 1    Neutral
# 2    Neutral
# 3   Positive
# 4    Neutral
# ..       ...
# 88   Neutral
# 89   Neutral
# 90   Neutral
# 91   Neutral
# 92  Positive
#
# [93 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df1['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df1['user_id_str'].plot(kind='hist', bins=20, title='user_id_str')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df1['Subjectivity'].plot(kind='hist', bins=20, title='Subjectivity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df1['Polarity'].plot(kind='hist', bins=20, title='Polarity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df1.groupby('TextBlob').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df1.plot(kind='scatter', x='Unnamed: 0', y='user_id_str', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df1.plot(kind='scatter', x='user_id_str', y='Subjectivity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df1.plot(kind='scatter', x='Subjectivity', y='Polarity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['user_id_str']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df1.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('TextBlob')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='TextBlob', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('user_id_str')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['Subjectivity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df1.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('TextBlob')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='TextBlob', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('Subjectivity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Unnamed: 0']
#   ys = series['Polarity']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df1.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('TextBlob')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='TextBlob', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('Polarity')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Unnamed: 0']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Unnamed: 0'}, axis=1)
#               .sort_values('Unnamed: 0', ascending=True))
#   xs = counted['Unnamed: 0']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df1.sort_values('Unnamed: 0', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('TextBlob')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='TextBlob', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Unnamed: 0')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df1['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df1['user_id_str'].plot(kind='line', figsize=(8, 4), title='user_id_str')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df1['Subjectivity'].plot(kind='line', figsize=(8, 4), title='Subjectivity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df1['Polarity'].plot(kind='line', figsize=(8, 4), title='Polarity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df1['TextBlob'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df1, x='Unnamed: 0', y='TextBlob', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df1['TextBlob'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df1, x='user_id_str', y='TextBlob', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df1['TextBlob'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df1, x='Subjectivity', y='TextBlob', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df1['TextBlob'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df1, x='Polarity', y='TextBlob', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
